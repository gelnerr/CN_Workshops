# %% [markdown]
# <center>
#
# ## Code Ninjas - Boss Badge Level 5
# # 🐍 Python Capstone: The Text Adventure Game
#
# </center>
#
# ---
# ### 🥷 Ninja Name: ________________

# %% [markdown]
# # Putting It All Together
# Welcome to the final level! In Microsoft MakeCode Arcade, games run continuously in the background until the player wins or loses their last life. This is called the **Game Loop**.
#
# In Python text games, we build our own Game Loop using a **`while`** loop! As long as the player's health is greater than 0, the loop keeps asking them what they want to do.
#
# Run the cell below to play a mini text adventure!

# %%
# 🟢 RUN ME: Click here and press Shift + Enter
print("You wake up in a dark cave. There are two paths: 'left' and 'right'.")
choice = input("Which way do you go? ")

if choice == "left":
    print("You found a chest full of gold! You win! 🏆")
elif choice == "right":
    print("Oh no! A trap door opens. Game Over. 💀")
else:
    print("You just stood there and fell asleep. Game Over. 💤")

# %% [markdown]
# ### 🐛 Challenge 1: Debugging the Game Loop
# A game loop only works if the code inside it is properly indented, and the loop checks the right variable.
#
# This game is supposed to keep going while the player has lives, but it is broken! Fix the `while` loop condition and the indentation so the game runs.

# %%
# 🛠️ DEBUG ME: Fix the while loop condition to check 'lives', and fix the indentation!
lives = 3

while health > 0:  # Wait, is the variable called health or lives?
print("You have", lives, "lives left. Keep fighting!")
lives = lives - 1

# %% [markdown]
# ---
# ## Section 2: Checking the Inventory (Lists + Ifs)
#
# In a lot of games, you can only open a door if you picked up the key earlier. In Python, we can check if an item is inside our list by using the **`in`** keyword!
#
# Run the code below to see how Python checks your inventory.

# %%
# 🟢 RUN ME: Checking lists with 'in'
my_items = ["Map", "Torch", "Magic Key"]

if "Magic Key" in my_items:
    print("The door unlocks! You may enter. 🚪✨")
else:
    print("The door is locked tight. You need a key.")

# %% [markdown]
# ### 🧩 Challenge 2: Fill in the Blanks (The Boss Fight)
# Let's combine lists, randomness, and conditionals! You are facing a monster, and your attack damage is completely random depending on which weapon you pull out of your bag.
#
# Fill in the missing `___` to finish the combat system.

# %%
# ✏️ SOLVE ME: Fill in the missing commands.
import random

weapons = ["Wooden Stick", "Iron Sword", "Fire Wand"]

# 1. Use random.choice to pick a weapon from the list!
my_weapon = random.___( weapons )

print("You pulled out a", my_weapon, "!")

# 2. Use an 'if' statement to check if the weapon is the Fire Wand
___ my_weapon == "Fire Wand":
    print("CRITICAL HIT! You defeated the monster instantly! 🔥")
___:
    print("You swing your weapon, but the monster escapes!")

# %% [markdown]
# ---
# ## 🏆 Final Capstone Boss: The Endless Dungeon
#
# This is it, Ninja! Your ultimate test. You are going to build a Game Loop that spawns random enemies.
#
# As long as the player has health, they will be asked if they want to 'fight' or 'run'. If they run, they lose 1 health.
#
# **Instructions:**
# 1. Finish the `while` loop so it runs as long as `health > 0`.
# 2. Use `input()` to ask the user if they want to 'fight' or 'run'.
# 3. Finish the `if / else` statement to handle their choice.
# 4. Make sure everything inside the loop is indented correctly!

# %%
# ⚔️ THE FINAL CAPSTONE: The Endless Dungeon!
import random

health = 3
enemies = ["Goblin", "Skeleton", "Slime", "Dragon"]

print("⚔️ WELCOME TO THE DUNGEON ⚔️")

# 1. Create the Game Loop
___ health > 0:
    current_enemy = random.choice(enemies)
    print("\nOh no! A wild", current_enemy, "appears!")
    print("You have", health, "HP remaining.")
    
    # 2. Get the player's choice
    action = ___("Do you want to 'fight' or 'run'? ")
    
    # 3. Handle the choice
    if action == "fight":
        print("You bravely fought the", current_enemy, "and won!")
        break # 'break' is a special command that exits the loop immediately so you win!
        
    elif action == "run":
        print("You ran away, but tripped and lost 1 HP!")
        health = health - 1
        
    else:
        print("Invalid choice! The monster hit you for 1 HP!")
        health = health - 1

print("\n--- GAME OVER ---")

# %% [markdown]
# ## 🎉 PYTHON BOSS BADGE COMPLETE! 🏆
# Congratulations, Ninja! You have mastered text-based syntax, variables, conditionals, loops, lists, and randomness. You just built a fully functioning Text Adventure game from scratch!
#
# **Show your Sensei your completed Endless Dungeon to claim your Python Boss Badge!**
