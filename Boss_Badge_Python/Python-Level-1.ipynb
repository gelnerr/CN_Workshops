# %% [markdown]
# <center>
#
# ## Code Ninjas - Boss Badge Level 1
# # 🐍 Python Foundations: From Blocks to Text
#
# </center>
#
# ---
# ### 🥷 Ninja Name: ________________

# %% [markdown]
# # Welcome to Python!
# If you have used Microsoft MakeCode Arcade, you are used to dragging and dropping colorful blocks to make your games. Python is a text-based language, which means instead of dragging blocks, we get to type the commands out!
#
# In MakeCode, if you wanted to show a message to the player, you used the `game.splash("Hello")` block.
#
# In Python, we use the `print()` function to do the exact same thing. Run the cell below using **Shift + Enter** to see it work.

# %%
# 🟢 RUN ME: Click here and press Shift + Enter
print("Hello, Python Ninjas! 🐍")

# %% [markdown]
# ### 🐛 Challenge 1: Debugging `print()`
# Uh oh, a bug squashed our code! Think about the text blocks in MakeCode—they always have a specific shape and "quotes" around the words to tell the computer it's a piece of text (a String).
#
# The exact same rule applies to Python. Fix the code below by adding the missing quotes so it runs without an error.

# %%
# 🛠️ DEBUG ME: This code is broken. Add the missing quotes (" ") to fix it!
print(Welcome to the Dojo!)

# %% [markdown]
# ---
# ## Section 2: Variables & Tilemaps
#
# In MakeCode, you probably built a lot of **Tilemaps**. When you design a tilemap, you assign a specific tile (like a brick wall, lava, or a treasure chest) to a specific grid coordinate on the map.
#
# **Variables** in Python work just like setting tiles on a tilemap! Instead of a grid coordinate, we use a **name** (like `player_name` or `health`), and instead of a tile image, we assign it a **value** (like `"Kai"` or `100`).
#
# In MakeCode, you had to click "Make a Variable" and drag a `set [myVar] to [0]` block. In Python, you just type the name, type an `=` sign, and give it the value. Run the cell below to see!

# %%
# 🟢 RUN ME: Creating variables in Python
player_name = "Kai"
health = 100
is_game_over = False

print(player_name, "has", health, "health remaining.")

# %% [markdown]
# ### 🧩 Challenge 2: Fill in the Blanks
# Now it's your turn. Just like setting a starting tile for your player, fill in the missing pieces `___` to set up your own variables, then print them out.

# %%
# ✏️ SOLVE ME: Replace the ___ with your own values.

favorite_color = "___"  # Don't forget the quotes for words!
ninja_belt_level = ___  # Put a number here (no quotes needed)

# Now let's print them together!
print("My favorite color is", favorite_color, "and I am on belt level", ninja_belt_level)

# %% [markdown]
# ---
# ## Section 3: Getting Input
#
# In MakeCode Arcade, if you wanted the player to type something, you used the `game.askForString("What is your name?")` block.
#
# In Python, we use the `input()` command. This command pauses the game and waits for the player to type an answer and press Enter. Run the code below and look at the text box that appears right under the code block!

# %%
# 🟢 RUN ME: Asking the user a question
superpower = input("If you could have one superpower, what would it be? ")

print("Whoa!", superpower, "is an awesome power to have! Just like jumping over obstacles in a tilemap!")

# %% [markdown]
# ---
# ## 🏆 Final Boss of Level 1: The Character Creator
#
# Let's put everything we learned together. We are going to ask the player for their character's name and their character's main item. Then, we will print out a welcome message for them to start their quest.
#
# Replace the `___` with the correct Python commands (`input` or `print`).

# %%
# ⚔️ FINAL BOSS: Fill in the missing commands!

# 1. Get the character's name using input()
char_name = ___( "Choose your character's name: " )

# 2. Get the character's item using input()
item = ___( "What starting item do you choose? " )

# 3. Output the final message using print()
___( "Ready to load the tilemap! ", char_name, "equips the", item, "!" )

# %% [markdown]
# ## 🎉 Level 1 Complete!
# Great job, Ninja! You've successfully learned how to use Python's `print()` and `input()` commands, and you know how to assign variables just like placing tiles on a map!
#
# **Show your Sensei your completed Character Creator to get your Level 1 Boss Badge stamp!**
